# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
sns.displot([0,1,2,3,4,5,6,7])

# %%
sns.distplot([8,0,3,9,5,7,1],hist=False)
# Out:
# C:\Users\RDRL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
x=[1,2,6,3,5,6,3,9,7,10]
y=[5,6,7,8,3,4,3,5,7,9]
sns.barplot(x,y,palette='rocket')
# Out:
# C:\Users\RDRL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.barplot(x,y,palette='pastel')
# Out:
# C:\Users\RDRL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.barplot(x,y,palette='bright')
# Out:
# C:\Users\RDRL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.barplot(x,y,palette='dark')
# Out:
# C:\Users\RDRL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
iris=sns.barplot(x,y,palette='colorblind')
# Out:
# C:\Users\RDRL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
iris=sns.load_dataset('iris')

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(data=titanic,x='alive')
# Out:
# <AxesSubplot:xlabel='alive', ylabel='count'>

# %%
sns.countplot(data=titanic,x='survived')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
titanic['pclass'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
titanic['pclass'].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
titanic['pclass'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
titanic['pclass'].plot(kind='hist',orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
titanic['pclass'].plot()
# Out:
# <AxesSubplot:>

# %%
titanic.plot.bar()
# Out:
# <AxesSubplot:>

# %%
titanic.plot.barh()
# Out:
# <AxesSubplot:>

# %%
titanic.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
titanic.plot.scatter(x='survived',y='age',c='fare',label='scatter for titanic')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
titanic.plot.hexbin(x='survived',y='age',gridsize=5)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
titanic.plot.pie(y='age')
# Out:
# <AxesSubplot:ylabel='age'>
